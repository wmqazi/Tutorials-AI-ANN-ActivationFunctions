# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def symmetrical_hardlimit(x):
    a = []
    for item in x:
        val = -1
        if item >= 0:
            val = 1
        a.append(val)
    return a


x = np.arange(-10., 20., 0.2)
x
sh = symmetrical_hardlimit(x)
plt.plot(x,sh)

ax = plt.gca()
#x.set_facecolor('#12161d')
#x.tick_params(axis='x', colors='#a3fc04')
#x.tick_params(axis='y', colors='#a3fc04')
plt.show()

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def symmetrical_hardlimit(x):
    a = []
    for item in x:
        val = -1
        if item >= 0:
            val = 1
        a.append(val)
        print(f"{item} = {val}" )
    return a


x = np.arange(-10., 20., 0.2)
x
sh = symmetrical_hardlimit(x)
# Out:
# -10.0 = -1
# -9.8 = -1
# -9.600000000000001 = -1
# -9.400000000000002 = -1
# -9.200000000000003 = -1
# -9.000000000000004 = -1
# -8.800000000000004 = -1
# -8.600000000000005 = -1
# -8.400000000000006 = -1
# -8.200000000000006 = -1
# -8.000000000000007 = -1
# -7.800000000000008 = -1
# -7.6000000000000085 = -1
# -7.400000000000009 = -1
# -7.20000000000001 = -1
# -7.000000000000011 = -1
# -6.800000000000011 = -1
# -6.600000000000012 = -1
# -6.400000000000013 = -1
# -6.2000000000000135 = -1
# -6.000000000000014 = -1
# -5.800000000000015 = -1
# -5.600000000000016 = -1
# -5.400000000000016 = -1
# -5.200000000000017 = -1
# -5.000000000000018 = -1
# -4.8000000000000185 = -1
# -4.600000000000019 = -1
# -4.40000000000002 = -1
# -4.200000000000021 = -1
# -4.000000000000021 = -1
# -3.800000000000022 = -1
# -3.6000000000000227 = -1
# -3.4000000000000234 = -1
# -3.200000000000024 = -1
# -3.000000000000025 = -1
# -2.8000000000000256 = -1
# -2.6000000000000263 = -1
# -2.400000000000027 = -1
# ...
